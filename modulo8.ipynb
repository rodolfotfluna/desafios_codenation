# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
#Armazenando as inscrições para serem utilizadas no arquivo de respostas.

df_resp = pd.DataFrame()

df_resp['NU_INSCRICAO'] = df_test['NU_INSCRICAO']

# %%
df_test.columns
# Out:
# Index(['NU_INSCRICAO', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE',
#        'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'TP_DEPENDENCIA_ADM_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_SABATISTA', 'IN_GESTANTE',
#        'IN_IDOSO', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT',
#        'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'TP_LINGUA',
#        'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
#        'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002',
#        'Q006', 'Q024', 'Q025', 'Q026', 'Q027', 'Q047'],
#       dtype='object')

# %%
#Selecionando os valores numéricos para a regressão.

df_test = df_test.select_dtypes(include=['int64','float64'])

# %%
df_test.corr()
# Out:
#                         CO_UF_RESIDENCIA  NU_IDADE  TP_COR_RACA  \
# CO_UF_RESIDENCIA                1.000000 -0.027277    -0.223924
# NU_IDADE                       -0.027277  1.000000     0.006029
# TP_COR_RACA                    -0.223924  0.006029     1.000000
# TP_NACIONALIDADE                0.003637 -0.004572     0.027840
# TP_ST_CONCLUSAO                 0.044634 -0.256723     0.008878
# TP_ANO_CONCLUIU                -0.055107  0.679562    -0.002415
# TP_ESCOLA                       0.048962 -0.305114    -0.037259
# TP_ENSINO                       0.027055  0.530718     0.023418
# IN_TREINEIRO                   -0.046836 -0.293714     0.033100
# TP_DEPENDENCIA_ADM_ESC          0.072562 -0.067555    -0.152762
# IN_BAIXA_VISAO                  0.020108  0.009528    -0.027071
# IN_CEGUEIRA                          NaN       NaN          NaN
# IN_SURDEZ                      -0.007103 -0.003327    -0.017164
# IN_DISLEXIA                          NaN       NaN          NaN
# IN_DISCALCULIA                       NaN       NaN          NaN
# IN_SABATISTA                   -0.032106  0.005537    -0.001096
# IN_GESTANTE                     0.015271 -0.006232    -0.024276
# IN_IDOSO                             NaN       NaN          NaN
# TP_PRESENCA_CN                 -0.000759 -0.272671     0.004696
# TP_PRESENCA_CH                 -0.000759 -0.272671     0.004696
# TP_PRESENCA_LC                 -0.005174 -0.273532     0.004758
# NU_NOTA_CN                      0.083600 -0.105278    -0.159068
# NU_NOTA_CH                      0.135885 -0.048229    -0.161977
# NU_NOTA_LC                      0.143118 -0.079171    -0.158654
# TP_LINGUA                      -0.101718  0.081890     0.119440
# TP_STATUS_REDACAO              -0.054463  0.054020     0.030188
# NU_NOTA_COMP1                   0.097031 -0.124681    -0.111649
# NU_NOTA_COMP2                   0.062417 -0.151605    -0.097166
# NU_NOTA_COMP3                   0.072866 -0.152863    -0.106149
# NU_NOTA_COMP4                   0.093678 -0.155038    -0.113439
# NU_NOTA_COMP5                   0.055288 -0.128243    -0.093965
# NU_NOTA_REDACAO                 0.084533 -0.161202    -0.117604
#
#                         TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# CO_UF_RESIDENCIA                0.003637         0.044634        -0.055107
# NU_IDADE                       -0.004572        -0.256723         0.679562
# TP_COR_RACA                     0.027840         0.008878        -0.002415
# TP_NACIONALIDADE                1.000000         0.020665        -0.021385
# TP_ST_CONCLUSAO                 0.020665         1.000000        -0.596560
# TP_ANO_CONCLUIU                -0.021385        -0.596560         1.000000
# TP_ESCOLA                      -0.010738         0.154720        -0.428168
# TP_ENSINO                       0.079272              NaN              NaN
# IN_TREINEIRO                    0.012710         0.527566        -0.252302
# TP_DEPENDENCIA_ADM_ESC         -0.021102              NaN              NaN
# IN_BAIXA_VISAO                 -0.006412        -0.001388        -0.008012
# IN_CEGUEIRA                          NaN              NaN              NaN
# IN_SURDEZ                      -0.003205        -0.013357        -0.000551
# IN_DISLEXIA                          NaN              NaN              NaN
# IN_DISCALCULIA                       NaN              NaN              NaN
# IN_SABATISTA                    0.001036        -0.020251         0.009711
# IN_GESTANTE                    -0.004533         0.016930        -0.004036
# IN_IDOSO                             NaN              NaN              NaN
# TP_PRESENCA_CN                 -0.024942         0.080982        -0.218775
# TP_PRESENCA_CH                 -0.024942         0.080982        -0.218775
# TP_PRESENCA_LC                 -0.021831         0.086170        -0.227607
# NU_NOTA_CN                     -0.060391        -0.075162         0.009162
# NU_NOTA_CH                     -0.059370        -0.112692         0.063830
# NU_NOTA_LC                     -0.079824        -0.104270         0.044894
# TP_LINGUA                      -0.012146        -0.019467         0.040844
# TP_STATUS_REDACAO               0.018637         0.007080        -0.011746
# NU_NOTA_COMP1                  -0.044226        -0.105960         0.027401
# NU_NOTA_COMP2                  -0.061297        -0.092896        -0.006863
# NU_NOTA_COMP3                  -0.067335        -0.098006        -0.006219
# NU_NOTA_COMP4                  -0.062960        -0.100944        -0.004171
# NU_NOTA_COMP5                  -0.050519        -0.086928        -0.009040
# NU_NOTA_REDACAO                -0.064910        -0.109049        -0.001123
#
#                         TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  \
# CO_UF_RESIDENCIA         0.048962   0.027055     -0.046836
# NU_IDADE                -0.305114   0.530718     -0.293714
# TP_COR_RACA             -0.037259   0.023418      0.033100
# TP_NACIONALIDADE        -0.010738   0.079272      0.012710
# TP_ST_CONCLUSAO          0.154720        NaN      0.527566
# TP_ANO_CONCLUIU         -0.428168        NaN     -0.252302
# TP_ESCOLA                1.000000  -0.050253     -0.247778
# TP_ENSINO               -0.050253   1.000000           NaN
# IN_TREINEIRO            -0.247778        NaN      1.000000
# TP_DEPENDENCIA_ADM_ESC   0.976290  -0.032146           NaN
# IN_BAIXA_VISAO          -0.006174  -0.008289     -0.011302
# IN_CEGUEIRA                   NaN        NaN           NaN
# IN_SURDEZ               -0.009587        NaN     -0.005649
# IN_DISLEXIA                   NaN        NaN           NaN
# IN_DISCALCULIA                NaN        NaN           NaN
# IN_SABATISTA             0.010190   0.009957     -0.019424
# IN_GESTANTE             -0.013560        NaN     -0.007990
# IN_IDOSO                      NaN        NaN           NaN
# TP_PRESENCA_CN           0.170994  -0.236073      0.105469
# TP_PRESENCA_CH           0.170994  -0.236073      0.105469
# TP_PRESENCA_LC           0.174481  -0.255366      0.109647
# NU_NOTA_CN               0.102662  -0.113558     -0.009669
# NU_NOTA_CH               0.054730  -0.094929     -0.032181
# NU_NOTA_LC               0.050485  -0.070557     -0.004934
# TP_LINGUA               -0.036728   0.065490     -0.048790
# TP_STATUS_REDACAO       -0.016245   0.087879     -0.008688
# NU_NOTA_COMP1            0.059388  -0.120581     -0.002073
# NU_NOTA_COMP2            0.090019  -0.159612     -0.013833
# NU_NOTA_COMP3            0.090184  -0.155955     -0.023881
# NU_NOTA_COMP4            0.102471  -0.157010     -0.019524
# NU_NOTA_COMP5            0.084356  -0.122173     -0.004485
# NU_NOTA_REDACAO          0.097388  -0.160772     -0.014277
#
#                         TP_DEPENDENCIA_ADM_ESC  ...  NU_NOTA_CH  NU_NOTA_LC  \
# CO_UF_RESIDENCIA                      0.072562  ...    0.135885    0.143118
# NU_IDADE                             -0.067555  ...   -0.048229   -0.079171
# TP_COR_RACA                          -0.152762  ...   -0.161977   -0.158654
# TP_NACIONALIDADE                     -0.021102  ...   -0.059370   -0.079824
# TP_ST_CONCLUSAO                            NaN  ...   -0.112692   -0.104270
# TP_ANO_CONCLUIU                            NaN  ...    0.063830    0.044894
# TP_ESCOLA                             0.976290  ...    0.054730    0.050485
# TP_ENSINO                            -0.032146  ...   -0.094929   -0.070557
# IN_TREINEIRO                               NaN  ...   -0.032181   -0.004934
# TP_DEPENDENCIA_ADM_ESC                1.000000  ...    0.286145    0.274803
# IN_BAIXA_VISAO                       -0.009610  ...   -0.028210   -0.025795
# IN_CEGUEIRA                                NaN  ...         NaN         NaN
# IN_SURDEZ                                  NaN  ...         NaN         NaN
# IN_DISLEXIA                                NaN  ...         NaN         NaN
# IN_DISCALCULIA                             NaN  ...         NaN         NaN
# IN_SABATISTA                          0.013248  ...   -0.002503    0.018154
# IN_GESTANTE                                NaN  ...    0.007396   -0.020893
# IN_IDOSO                                   NaN  ...         NaN         NaN
# TP_PRESENCA_CN                        0.096697  ...         NaN    0.065279
# TP_PRESENCA_CH                        0.096697  ...         NaN    0.065279
# TP_PRESENCA_LC                        0.103375  ...    0.058824         NaN
# NU_NOTA_CN                            0.308807  ...    0.598574    0.545801
# NU_NOTA_CH                            0.286145  ...    1.000000    0.679993
# NU_NOTA_LC                            0.274803  ...    0.679993    1.000000
# TP_LINGUA                            -0.136473  ...   -0.241585   -0.258362
# TP_STATUS_REDACAO                    -0.039044  ...   -0.105134   -0.132482
# NU_NOTA_COMP1                         0.234154  ...    0.434293    0.429795
# NU_NOTA_COMP2                         0.225320  ...    0.467964    0.435176
# NU_NOTA_COMP3                         0.232888  ...    0.492713    0.447566
# NU_NOTA_COMP4                         0.253560  ...    0.485807    0.453682
# NU_NOTA_COMP5                         0.255042  ...    0.478836    0.422711
# NU_NOTA_REDACAO                       0.272487  ...    0.537141    0.495745
#
#                         TP_LINGUA  TP_STATUS_REDACAO  NU_NOTA_COMP1  \
# CO_UF_RESIDENCIA        -0.101718          -0.054463       0.097031
# NU_IDADE                 0.081890           0.054020      -0.124681
# TP_COR_RACA              0.119440           0.030188      -0.111649
# TP_NACIONALIDADE        -0.012146           0.018637      -0.044226
# TP_ST_CONCLUSAO         -0.019467           0.007080      -0.105960
# TP_ANO_CONCLUIU          0.040844          -0.011746       0.027401
# TP_ESCOLA               -0.036728          -0.016245       0.059388
# TP_ENSINO                0.065490           0.087879      -0.120581
# IN_TREINEIRO            -0.048790          -0.008688      -0.002073
# TP_DEPENDENCIA_ADM_ESC  -0.136473          -0.039044       0.234154
# IN_BAIXA_VISAO           0.023927          -0.003361       0.000313
# IN_CEGUEIRA                   NaN                NaN            NaN
# IN_SURDEZ               -0.018276                NaN            NaN
# IN_DISLEXIA                   NaN                NaN            NaN
# IN_DISCALCULIA                NaN                NaN            NaN
# IN_SABATISTA            -0.015113           0.008516       0.022155
# IN_GESTANTE             -0.004467          -0.002376      -0.011638
# IN_IDOSO                      NaN                NaN            NaN
# TP_PRESENCA_CN          -0.043005          -0.050388       0.059634
# TP_PRESENCA_CH          -0.043005          -0.050388       0.059634
# TP_PRESENCA_LC          -0.041664                NaN            NaN
# NU_NOTA_CN              -0.225171          -0.081838       0.352608
# NU_NOTA_CH              -0.241585          -0.105134       0.434293
# NU_NOTA_LC              -0.258362          -0.132482       0.429795
# TP_LINGUA                1.000000           0.034703      -0.144796
# TP_STATUS_REDACAO        0.034703           1.000000      -0.569033
# NU_NOTA_COMP1           -0.144796          -0.569033       1.000000
# NU_NOTA_COMP2           -0.149953          -0.464106       0.758740
# NU_NOTA_COMP3           -0.144210          -0.434157       0.755680
# NU_NOTA_COMP4           -0.134253          -0.469443       0.818071
# NU_NOTA_COMP5           -0.125126          -0.246324       0.546895
# NU_NOTA_REDACAO         -0.157334          -0.479247       0.858868
#
#                         NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  \
# CO_UF_RESIDENCIA             0.062417       0.072866       0.093678
# NU_IDADE                    -0.151605      -0.152863      -0.155038
# TP_COR_RACA                 -0.097166      -0.106149      -0.113439
# TP_NACIONALIDADE            -0.061297      -0.067335      -0.062960
# TP_ST_CONCLUSAO             -0.092896      -0.098006      -0.100944
# TP_ANO_CONCLUIU             -0.006863      -0.006219      -0.004171
# TP_ESCOLA                    0.090019       0.090184       0.102471
# TP_ENSINO                   -0.159612      -0.155955      -0.157010
# IN_TREINEIRO                -0.013833      -0.023881      -0.019524
# TP_DEPENDENCIA_ADM_ESC       0.225320       0.232888       0.253560
# IN_BAIXA_VISAO               0.005911       0.009798       0.012553
# IN_CEGUEIRA                       NaN            NaN            NaN
# IN_SURDEZ                         NaN            NaN            NaN
# IN_DISLEXIA                       NaN            NaN            NaN
# IN_DISCALCULIA                    NaN            NaN            NaN
# IN_SABATISTA                 0.021653       0.014938       0.021829
# IN_GESTANTE                 -0.037178      -0.023598      -0.017047
# IN_IDOSO                          NaN            NaN            NaN
# TP_PRESENCA_CN               0.048082       0.040634       0.060370
# TP_PRESENCA_CH               0.048082       0.040634       0.060370
# TP_PRESENCA_LC                    NaN            NaN            NaN
# NU_NOTA_CN                   0.390462       0.409225       0.395787
# NU_NOTA_CH                   0.467964       0.492713       0.485807
# NU_NOTA_LC                   0.435176       0.447566       0.453682
# TP_LINGUA                   -0.149953      -0.144210      -0.134253
# TP_STATUS_REDACAO           -0.464106      -0.434157      -0.469443
# NU_NOTA_COMP1                0.758740       0.755680       0.818071
# NU_NOTA_COMP2                1.000000       0.873625       0.810890
# NU_NOTA_COMP3                0.873625       1.000000       0.829071
# NU_NOTA_COMP4                0.810890       0.829071       1.000000
# NU_NOTA_COMP5                0.645249       0.660097       0.619196
# NU_NOTA_REDACAO              0.918151       0.926185       0.912078
#
#                         NU_NOTA_COMP5  NU_NOTA_REDACAO
# CO_UF_RESIDENCIA             0.055288         0.084533
# NU_IDADE                    -0.128243        -0.161202
# TP_COR_RACA                 -0.093965        -0.117604
# TP_NACIONALIDADE            -0.050519        -0.064910
# TP_ST_CONCLUSAO             -0.086928        -0.109049
# TP_ANO_CONCLUIU             -0.009040        -0.001123
# TP_ESCOLA                    0.084356         0.097388
# TP_ENSINO                   -0.122173        -0.160772
# IN_TREINEIRO                -0.004485        -0.014277
# TP_DEPENDENCIA_ADM_ESC       0.255042         0.272487
# IN_BAIXA_VISAO              -0.003785         0.005208
# IN_CEGUEIRA                       NaN              NaN
# IN_SURDEZ                         NaN              NaN
# IN_DISLEXIA                       NaN              NaN
# IN_DISCALCULIA                    NaN              NaN
# IN_SABATISTA                 0.016091         0.021621
# IN_GESTANTE                 -0.014690        -0.023501
# IN_IDOSO                          NaN              NaN
# TP_PRESENCA_CN               0.031505         0.053070
# TP_PRESENCA_CH               0.031505         0.053070
# TP_PRESENCA_LC                    NaN              NaN
# NU_NOTA_CN                   0.395588         0.442692
# NU_NOTA_CH                   0.478836         0.537141
# NU_NOTA_LC                   0.422711         0.495745
# TP_LINGUA                   -0.125126        -0.157334
# TP_STATUS_REDACAO           -0.246324        -0.479247
# NU_NOTA_COMP1                0.546895         0.858868
# NU_NOTA_COMP2                0.645249         0.918151
# NU_NOTA_COMP3                0.660097         0.926185
# NU_NOTA_COMP4                0.619196         0.912078
# NU_NOTA_COMP5                1.000000         0.810889
# NU_NOTA_REDACAO              0.810889         1.000000
#
# [32 rows x 32 columns]

# %%
features = [
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'NU_NOTA_LC',
    'NU_NOTA_REDACAO',
    'NU_NOTA_COMP1',
    'NU_NOTA_COMP2',
    'NU_NOTA_COMP3',
    'NU_NOTA_COMP4',
    'NU_NOTA_COMP5']


features_corr = [
    'NU_NOTA_MT',
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'NU_NOTA_LC',
    'NU_NOTA_REDACAO',
    'NU_NOTA_COMP1',
    'NU_NOTA_COMP2',
    'NU_NOTA_COMP3',
    'NU_NOTA_COMP4',
    'NU_NOTA_COMP5']

# %%
df_train[features].isnull().sum()
# Out:
# NU_NOTA_CN         3389
# NU_NOTA_CH         3389
# NU_NOTA_LC         3597
# NU_NOTA_REDACAO    3597
# NU_NOTA_COMP1      3597
# NU_NOTA_COMP2      3597
# NU_NOTA_COMP3      3597
# NU_NOTA_COMP4      3597
# NU_NOTA_COMP5      3597
# dtype: int64

# %%
df_train = df_train.loc[
      (df_train['NU_NOTA_CN'].notnull())  & (df_train['NU_NOTA_CN'] != 0) & (df_train['NU_NOTA_CH'].notnull())      & (df_train['NU_NOTA_CH'] != 0) 
    & (df_train['NU_NOTA_LC'].notnull())  & (df_train['NU_NOTA_LC'] != 0) & (df_train['NU_NOTA_REDACAO'].notnull()) & (df_train['NU_NOTA_REDACAO'] != 0)    
]

# %%
df_test = df_test.loc[
      (df_test['NU_NOTA_CN'].notnull())  & (df_test['NU_NOTA_CN'] != 0) & (df_test['NU_NOTA_CH'].notnull())      & (df_test['NU_NOTA_CH'] != 0) 
    & (df_test['NU_NOTA_LC'].notnull())  & (df_test['NU_NOTA_LC'] != 0) & (df_test['NU_NOTA_REDACAO'].notnull()) & (df_test['NU_NOTA_REDACAO'] != 0)    
]

# %%
df_test[features].isnull().sum()
# Out:
# NU_NOTA_CN         0
# NU_NOTA_CH         0
# NU_NOTA_LC         0
# NU_NOTA_REDACAO    0
# NU_NOTA_COMP1      0
# NU_NOTA_COMP2      0
# NU_NOTA_COMP3      0
# NU_NOTA_COMP4      0
# NU_NOTA_COMP5      0
# dtype: int64

# %%
df_test['NU_NOTA_COMP1'].fillna(0,inplace=True)
df_test['NU_NOTA_COMP2'].fillna(0,inplace=True)
df_test['NU_NOTA_COMP3'].fillna(0,inplace=True)
df_test['NU_NOTA_COMP4'].fillna(0,inplace=True)
df_test['NU_NOTA_COMP5'].fillna(0,inplace=True)

df_train['NU_NOTA_COMP1'].fillna(0,inplace=True)
df_train['NU_NOTA_COMP2'].fillna(0,inplace=True)
df_train['NU_NOTA_COMP3'].fillna(0,inplace=True)
df_train['NU_NOTA_COMP4'].fillna(0,inplace=True)
df_train['NU_NOTA_COMP5'].fillna(0,inplace=True)

# %%
y_train = df_train['NU_NOTA_MT']
x_train = df_train[features]
x_test = df_test[features]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()  
x_train = sc.fit_transform(x_train)  
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_test = linear_regression.predict(x_test)

y_pred_train = linear_regression.predict(x_train)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_train, y_pred_train).round(8)  )
print('MSE:', metrics.mean_squared_error(y_train, y_pred_train).round(8) )  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_train)).round(8))
# Out:
# MAE: 60.94270651
# MSE: 5867.44396654
# RMSE: 76.5992426

# %%
#Salvando as notas

df_resp['NU_NOTA_MT'] = np.around(y_pred_test,2)

# %%
df_resp.to_csv('answer.csv', index=False, header=True)
